# %% [markdown]
# <a href="https://colab.research.google.com/github/ThesalonikaValencia/PembelajaranMesin/blob/main/TUGAS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset ='/content/WORLD HAPPINESS REPORT_2023.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#               country                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
# ..                ...                           ...              ...
# 132  Congo (Kinshasa)            Sub-Saharan Africa            3.207
# 133          Zimbabwe            Sub-Saharan Africa            3.204
# 134      Sierra Leone            Sub-Saharan Africa            3.138
# 135           Lebanon  Middle East and North Africa            2.392
# 136       Afghanistan                    South Asia            1.859
#
#      gdp_per_capita  social_support  healthy_life_expectancy  \
# 0             1.888           1.585                    0.535
# ...

# %%
data.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# ...

# %%
print(data.dtypes)
# Out:
# country                          object
# region                           object
# happiness_score                 float64
# gdp_per_capita                  float64
# social_support                  float64
# healthy_life_expectancy         float64
# freedom_to_make_life_choices    float64
# generosity                      float64
# perceptions_of_corruption       float64
# dtype: object

# %%
datanoid = data.drop(data.columns[4], axis= 1)

# %%
datanoid
# Out:
#               country                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
# ..                ...                           ...              ...
# 132  Congo (Kinshasa)            Sub-Saharan Africa            3.207
# 133          Zimbabwe            Sub-Saharan Africa            3.204
# 134      Sierra Leone            Sub-Saharan Africa            3.138
# 135           Lebanon  Middle East and North Africa            2.392
# 136       Afghanistan                    South Asia            1.859
#
#      gdp_per_capita  healthy_life_expectancy  freedom_to_make_life_choices  \
# ...

# %%
data.describe()
# Out:
#        happiness_score  gdp_per_capita  social_support  \
# count       137.000000      137.000000      137.000000
# mean          5.539796        1.406985        1.156212
# std           1.139929        0.432963        0.326322
# min           1.859000        0.000000        0.000000
# 25%           4.724000        1.099000        0.962000
# 50%           5.684000        1.449000        1.227000
# 75%           6.334000        1.798000        1.401000
# max           7.804000        2.200000        1.620000
#
#        healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# count               136.000000                    137.000000  137.000000
# mean                  0.366176                      0.540000    0.148474
# std                   0.156691                      0.149501    0.076053
# min                   0.000000                      0.000000    0.000000
# 25%                   0.248500                      0.455000    0.097000
# ...

# %%
data.loc[:,"happiness_score":].corr()
# Out:
#                               happiness_score  gdp_per_capita  social_support  \
# happiness_score                      1.000000        0.784342        0.834604
# gdp_per_capita                       0.784342        1.000000        0.737993
# social_support                       0.834604        0.737993        1.000000
# healthy_life_expectancy              0.746699        0.837518        0.725334
# freedom_to_make_life_choices         0.662909        0.451405        0.541832
# generosity                           0.043680       -0.156780        0.035736
# perceptions_of_corruption            0.471913        0.436979        0.272538
#
#                               healthy_life_expectancy  \
# happiness_score                              0.746699
# gdp_per_capita                               0.837518
# social_support                               0.725334
# healthy_life_expectancy                      1.000000
# freedom_to_make_life_choices                 0.414965
# ...

# %%
# @title happiness_score vs gdp_per_capita

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='happiness_score', y='gdp_per_capita', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Dengan API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-3cffabef-a061-4f76-b9ee-df06feaaf05b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cffabef-a061-4f76-b9ee-df06feaaf05b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "world happiness report"
# Out:
# ...
# ref                                                           title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# unsdsn/world-happiness                                        World Happiness Report                               37KB  2019-11-27 04:41:47         289977       4080  0.85294116
# ajaypalsinghlo/world-happiness-report-2021                    World Happiness Report 2021                          55KB  2021-03-22 16:51:01          72935       1346  0.9705882
# PromptCloudHQ/world-happiness-report-2019                     World Happiness Report 2019                           4KB  2019-03-20 09:39:07          23902        410  1.0
# ...

# %%
# !kaggle datasets download unsdsn/world-happiness
# Out:
# ...
#   0% 0.00/36.8k [00:00<?, ?B/s]
# 100% 36.8k/36.8k [00:00<00:00, 77.5MB/s]

# %%
# !unzip /content/world-happiness.zip
# Out:
# Archive:  /content/world-happiness.zip
#   inflating: 2015.csv
#   inflating: 2016.csv
#   inflating: 2017.csv
#   inflating: 2018.csv
#   inflating: 2019.csv

# %%
pd.read_csv('/content/2015.csv')
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...
